# %%
# !pip install dnspython

import pymongo as pm
import pandas as pd
import numpy as np
import io

from google.colab import files

client = pm.MongoClient('mongodb+srv://antonio:fenceapp@fence-httxx.mongodb.net/test?retryWrites=true&w=majority')
db = client['fencedb']
# Out:
# ...
#      |████████████████████████████████| 194kB 1.8MB/s
# ...

# %%
def upload_files ():
  uploaded = files.upload()
  for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
    df = pd.read_csv(io.StringIO(uploaded[fn].decode('utf-8')), index_col=0, sep=';')
    return df

# %%
df = upload_files()
# Out:
#      <input type="file" id="files-570a5712-3ccd-44b7-b265-293b8808a92e" name="files[]" multiple disabled />
#      <output id="result-570a5712-3ccd-44b7-b265-293b8808a92e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 6-dimensions-for-website-2015-12-08-0-100.csv to 6-dimensions-for-website-2015-12-08-0-100.csv
# User uploaded file "6-dimensions-for-website-2015-12-08-0-100.csv" with length 4264 bytes

# %%
df = df.replace('#NULL!', np.NaN)

# %%
cultural_attributes = db['countries']

for index, row in df.iterrows():

  record = {}

  record['name'] = row['country']
  record['pdi'] = row['pdi']
  record['idv'] = row['idv']
  record['mas'] = row['mas']
  record['uai'] = row['uai']
  record['ltowvs'] = row['ltowvs']
  record['ivr'] = row['ivr']

  cultural_attributes.insert_one(record)
